# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.load(r"E:\modules\data\attention_0db.npy")
B = np.load(r"E:\modules\data\attention_-5db.npy")
C = np.load(r"E:\modules\data\attention_-10db.npy")

A_mean = np.mean(A, axis =0)
B_mean = np.mean(B, axis =0)
C_mean = np.mean(C, axis =0)

A_label = np.load(r"E:\modules\data\attention_0db_label.npy")
B_label = np.load(r"E:\modules\data\attention_-5db_label.npy")
C_label = np.load(r"E:\modules\data\attention_-10db_label.npy")

# %%
plt.matshow(A_mean,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\0dB_average.svg", dpi=600,format="svg")
plt.matshow(B_mean,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\-5dB_average.svg", dpi=600,format="svg")
plt.matshow(C_mean,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\-10dB_average.svg", dpi=600,format="svg")

# %%
A_index1 = np.argwhere(A_label==-60)[:,0]
A_mean_1 = np.mean(A[A_index1],axis = 0)
plt.matshow(A_mean_1,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\A_-60.svg", dpi=600,format="svg")
A_index2 = np.argwhere(A_label==-50)[:,0]
A_mean_2 = np.mean(A[A_index2],axis = 0)
plt.matshow(A_mean_2,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\A_-50.svg", dpi=600,format="svg")
A_index3 = np.argwhere(A_label==-40)[:,0]
A_mean_3 = np.mean(A[A_index3],axis = 0)
plt.matshow(A_mean_3,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\A_-40.svg", dpi=600,format="svg")
A_index4 = np.argwhere(A_label==-30)[:,0]
A_mean_4 = np.mean(A[A_index4],axis = 0)
plt.matshow(A_mean_4,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\A_-30.svg", dpi=600,format="svg")
A_index5 = np.argwhere(A_label==-20)[:,0]
A_mean_5 = np.mean(A[A_index5],axis = 0)
plt.matshow(A_mean_5,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\A_-20.svg", dpi=600,format="svg")
A_index6 = np.argwhere(A_label==-10)[:,0]
A_mean_6 = np.mean(A[A_index6],axis = 0)
plt.matshow(A_mean_6,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\A_-10.svg", dpi=600,format="svg")
A_index7 = np.argwhere(A_label==0)[:,0]
A_mean_7 = np.mean(A[A_index7],axis = 0)
plt.matshow(A_mean_7,cmap=plt.cm.Blues)
plt.savefig(r"C:\Users\Shilelon\Desktop\DOA_记录以及画图材料\A_0.svg", dpi=600,format="svg")

# %%
B_index1 = np.argwhere(B_label==-60)[:,0]
B_mean_1 = np.mean(B[B_index1],axis = 0)
plt.matshow(B_mean_1,cmap=plt.cm.Blues)
plt.show()
B_index2 = np.argwhere(B_label==-50)[:,0]
B_mean_2 = np.mean(B[B_index2],axis = 0)
plt.matshow(B_mean_2,cmap=plt.cm.Blues)
plt.show()
B_index3 = np.argwhere(B_label==-40)[:,0]
B_mean_3 = np.mean(B[B_index3],axis = 0)
plt.matshow(B_mean_3,cmap=plt.cm.Blues)
plt.show()
B_index4 = np.argwhere(B_label==-30)[:,0]
B_mean_4 = np.mean(B[B_index4],axis = 0)
plt.matshow(B_mean_4,cmap=plt.cm.Blues)
plt.show()
B_index5 = np.argwhere(B_label==-20)[:,0]
B_mean_5 = np.mean(B[B_index5],axis = 0)
plt.matshow(B_mean_5,cmap=plt.cm.Blues)
plt.show()
B_index6 = np.argwhere(B_label==-10)[:,0]
B_mean_6 = np.mean(B[B_index6],axis = 0)
plt.matshow(B_mean_6,cmap=plt.cm.Blues)
plt.show()
B_index7 = np.argwhere(B_label==0)[:,0]
B_mean_7 = np.mean(B[B_index7],axis = 0)
plt.matshow(B_mean_7,cmap=plt.cm.Blues)
plt.show()

# %%
C_index1 = np.argwhere(C_label==-60)[:,0]
C_mean_1 = np.mean(C[C_index1],axis = 0)
plt.matshow(C_mean_1,cmap=plt.cm.Blues)
plt.show()
C_index2 = np.argwhere(C_label==-50)[:,0]
C_mean_2 = np.mean(C[C_index2],axis = 0)
plt.matshow(C_mean_2,cmap=plt.cm.Blues)
plt.show()
C_index3 = np.argwhere(C_label==-40)[:,0]
C_mean_3 = np.mean(C[C_index3],axis = 0)
plt.matshow(C_mean_3,cmap=plt.cm.Blues)
plt.show()
C_index4 = np.argwhere(C_label==-30)[:,0]
C_mean_4 = np.mean(C[C_index4],axis = 0)
plt.matshow(C_mean_4,cmap=plt.cm.Blues)
plt.show()
C_index5 = np.argwhere(C_label==-20)[:,0]
C_mean_5 = np.mean(C[C_index5],axis = 0)
plt.matshow(C_mean_5,cmap=plt.cm.Blues)
plt.show()
C_index6 = np.argwhere(C_label==-10)[:,0]
C_mean_6 = np.mean(C[C_index6],axis = 0)
plt.matshow(C_mean_6,cmap=plt.cm.Blues)
plt.show()
C_index7 = np.argwhere(C_label==0)[:,0]
C_mean_7 = np.mean(C[C_index7],axis = 0)
plt.matshow(C_mean_7,cmap=plt.cm.Blues)
plt.show()

# %%
A_mean
# Out:
# array([[0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
#        [0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
#        [0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
#        [0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
# ...

# %%
# Out:
# array([[0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
#        [0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
#        [0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
#        [0.06112094, 0.05534361, 0.05974857, 0.0605926 , 0.06126736,
#         0.05941745, 0.05359591, 0.05986926, 0.06057316, 0.0595496 ,
#         0.05860962, 0.05395523, 0.05980905, 0.06006317, 0.06094857,
#         0.05982794, 0.05570797],
# ...
